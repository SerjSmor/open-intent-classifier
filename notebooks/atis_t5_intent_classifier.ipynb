# %% [markdown]
# # The goal
# This is an example on how to initialize the T5 based model that accepts dynamic labels.
# We will load the Atis dataset and then classify using it

# %% [markdown]
# ## Initialize model

# %%
from open_intent_classifier.model import IntentClassifier

model = IntentClassifier(device="cuda", verbose=True)
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565

# %% [markdown]
# ## Initialize dataset

# %%
import pandas as pd
from datasets import load_dataset

# we don't include any multi-label instances in order to simplify this classification

ATIS_INTENT_MAPPING = {
    'abbreviation': "Abbreviation and Fare Code Meaning Inquiry",
    'aircraft': "Aircraft Type Inquiry",
    'airfare': "Airfare and Fares Questions",
    'airline': "Airline Information Request",
    'airport': "Airport Information and Queries",
    'capacity': "Aircraft Seating Capacity Inquiry",
    'cheapest': "Cheapest Fare Inquiry",
    'city': "Airport Location Inquiry",
    'distance': "Airport Distance Inquiry",
    'flight': "Flight Booking Request",
    'flight_no': "Flight Number Inquiry",
    'flight_time': "Time Inquiry",
    'ground_fare': "Ground Transportation Cost Inquiry",
    'ground_service': "Ground Transportation Inquiry",
    'ground_service+ground_fare': "Airport Ground Transportation and Cost Query",
    'meal': "Inquiry about In-flight Meals",
    'quantity': "Flight Quantity Inquiry",
    'restriction': "Flight Restriction Inquiry"
}

def atis_convert_old_label_to_class_atis(old_label: str):
    if old_label in ATIS_INTENT_MAPPING:
        return ATIS_INTENT_MAPPING[old_label]
    return None


dataset = load_dataset("tuetschek/atis")
dataset.set_format(type="pandas")

df_train: pd.DataFrame = dataset["train"][:]
df_test: pd.DataFrame = dataset["test"][:]

df_train["label"] = df_train["intent"].apply(lambda label: atis_convert_old_label_to_class_atis(label))
df_test["label"] = df_test["intent"].apply(lambda label: atis_convert_old_label_to_class_atis(label))
df_train.dropna(subset=["label"], inplace=True)
df_test.dropna(subset=["label"], inplace=True)
# Out:
# datasets - INFO - PyTorch version 2.4.1 available.

# %% [markdown]
# ## Sort labels alphabetically - emperically improves performance for Atis dataset

# %%
labels = ATIS_INTENT_MAPPING.values()
sorted_labels = sorted(labels)
sorted_labels
# Out:
# ['Abbreviation and Fare Code Meaning Inquiry',
#  'Aircraft Seating Capacity Inquiry',
#  'Aircraft Type Inquiry',
#  'Airfare and Fares Questions',
#  'Airline Information Request',
#  'Airport Distance Inquiry',
#  'Airport Ground Transportation and Cost Query',
#  'Airport Information and Queries',
#  'Airport Location Inquiry',
#  'Cheapest Fare Inquiry',
#  'Flight Booking Request',
#  'Flight Number Inquiry',
#  'Flight Quantity Inquiry',
#  'Flight Restriction Inquiry',
#  'Ground Transportation Cost Inquiry',
#  'Ground Transportation Inquiry',
#  'Inquiry about In-flight Meals',
#  'Time Inquiry']

# %% [markdown]
# ## Run predictions

# %%
from tqdm import tqdm
predictions = []

for index, row in tqdm(df_test.iterrows()):
    text = row["text"]
    prediction = model.predict(text, sorted_labels)
    predictions.append(prediction)
# Out:
# 0it [00:00, ?it/s]/home/serj/dev/open-intent-classifier/venv/lib/python3.10/site-packages/transformers/generation/utils.py:1258: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# open_intent_classifier.model - DEBUG - Full prompt: Topic %% Customer: i would like to find a flight from charlotte to las vegas that makes a stop in st. louis.
# END MESSAGE
# Choose one topic that matches customer's issue.
#  Options:
# # Abbreviation and Fare Code Meaning Inquiry
# # Aircraft Seating Capacity Inquiry
# # Aircraft Type Inquiry
# # Airfare and Fares Questions
# # Airline Information Request
# # Airport Distance Inquiry
# # Airport Ground Transportation and Cost Query
# # Airport Information and Queries
# # Airport Location Inquiry
# # Cheapest Fare Inquiry
# # Flight Booking Request
# # Flight Number Inquiry
# # Flight Quantity Inquiry
# # Flight Restriction Inquiry
# # Ground Transportation Cost Inquiry
# # Ground Transportation Inquiry
# # Inquiry about In-flight Meals
# # Time Inquiry
#
# Class name:
# open_intent_classifier.model - DEBUG - Decoded output: Flight Booking Request
# 1it [00:00,  2.39it/s]open_intent_classifier.model - DEBUG - Full prompt: Topic %% Customer
request
# # Airport Distance Inquiry
# # Airport Ground Transportation and Cost Query
# # Airport Information and Queries
# # Airport Location Inquiry
# # Cheapest Fare Inquiry
# # Flight Booking Request
# # Flight Number Inquiry
# # Flight Quantity Inquiry
# # Flight Restriction Inquiry
# # Ground Transportation Cost Inquiry
# # Ground Transportation Inquiry
# # Inquiry about In-flight Meals
# # Time Inquiry
#
# Class name:
# open_intent_classifier.model - DEBUG - Decoded output: Airline Information Request
# open_intent_classifier.model - DEBUG - Full prompt: Topic %% Customer: find me all the round trip flights from burbank to milwaukee stopping in st. louis.
# END MESSAGE
# Choose one topic that matches customer's issue.
#  Options:
# # Abbreviation and Fare Code Meaning Inquiry
# # Aircraft Seating Capacity Inquiry
# # Aircraft Type Inquiry
# # Airfare and Fares Questions
# # Airline Information Request
# # Airport Distance Inquiry
# # Airport Ground Transportation and Cost Query
# # Airport Information and Queries
# # Airport Location Inquiry
# # Cheapest Fare Inquiry
# # Flight Booking Request
# # Flight Number Inquiry
# # Flight Quantity Inquiry
# # Flight Restriction Inquiry
# # Ground Transportation Cost Inquiry
# # Ground Transportation Inquiry
# # Inquiry about In-flight Meals
# # Time Inquiry
#
# Class name:
# open_intent_classifier.model - DEBUG - Decoded output: Flight Booking Request
# open_intent_classifier.model - DEBUG - Full prompt: Topic %% Customer: i 'd like to book two flights to westchester county.
# END MESSAGE
# Choose one topic that matches customer's issue.
#  Options:
# # Abbreviation and Fare Code Meaning Inquiry
# # Aircraft Seating Capacity Inquiry
# # Aircraft Type Inquiry
# # Airfare and Fares Questions
# # Airline Information Request
# # Airport Distance Inquiry
# # Airport Ground Transportation and Cost Query
# # Airport Information and Queries
# # Airport Location Inquiry
# # Cheapest Fare Inquiry
# # Flight Booking Request
# # Flight Number Inquiry
# # Flight Quantity Inquiry
# # Flight Restriction Inquiry
# # Ground Transportation Cost Inquiry
# # Ground Transportation Inquiry
# # Inquiry about In-flight Meals
# # Time Inquiry
#
# Class name:
# open_intent_classifier.model - DEBUG - Decoded output: Flight Booking Request
# open_intent_classifier.model - DEBUG - Full prompt: Topic %% Customer: i want to book a flight from salt lake city to westchester county.
# END MESSAGE
# Choose one topic that matches customer's issue.
#  Options:
# # Abbreviation and Fare Code Meaning Inquiry
# # Aircraft Seating Capacity Inquiry
# # Aircraft Type Inquiry
# # Airfare and Fares Questions
# # Airline Information Request
# # Airport Distance Inquiry
# # Airport Ground Transportation and Cost Query
# # Airport Information and Queries
# # Airport Location Inquiry
# # Cheapest Fare Inquiry
# # Flight Booking Request
# # Flight Number Inquiry
# # Flight Quantity Inquiry
# # Flight Restriction Inquiry
# # Ground Transportation Cost Inquiry
# # Ground Transportation Inquiry
# # Inquiry about In-flight Meals
# # Time Inquiry
#
# Class name:
# open_intent_classifier.model - DEBUG - Decoded output: Flight Booking Request
# open_intent_classifier.model - DEBUG - Full prompt: Topic %% Customer: tell me all the airports near westchester county.
# END MESSAGE
# Choose one topic that matches customer's issue.
#  Options:
# # Abbreviation and Fare Code Meaning Inquiry
# # Aircraft Seating Capacity Inquiry
# # Aircraft Type Inquiry
# # Airfare and Fares Questions
# # Airline Information Request
# # Airport Distance Inquiry
# # Airport Ground Transportation and Cost Query
# # Airport Information and Queries
# # Airport Location Inquiry
# # Cheapest Fare Inquiry
# # Flight Booking Request
# # Flight Number Inquiry
# # Flight Quantity Inquiry
# # Flight Restriction Inquiry
# # Ground Transportation Cost Inquiry
# # Ground Transportation Inquiry
# # Inquiry about In-flight Meals
# # Time Inquiry
#
# Class name:
# open_intent_classifier.model - DEBUG - Decoded output: Airport Location Inquiry
# 869it [00:22, 49.33it/s]open_intent_classifier.model - DEBUG - Full prompt: Topic %% Customer: i 'd like to book a flight from cincinnati to new york city on united airlines for next saturday.
# END MESSAGE
# Choose one topic that matches customer's issue.
#  Options:
# # Abbreviation and Fare Code Meaning Inquiry
# # Aircraft Seating Capacity Inquiry
# # Aircraft Type Inquiry
# # Airfare and Fares Questions
# # Airline Information Request
# # Airport Distance Inquiry
# # Airport Ground Transportation and Cost Query
# # Airport Information and Queries
# # Airport Location Inquiry
# # Cheapest Fare Inquiry
# # Flight Booking Request
# # Flight Number Inquiry
# # Flight Quantity Inquiry
# # Flight Restriction Inquiry
# # Ground Transportation Cost Inquiry
# # Ground Transportation Inquiry
# # Inquiry about In-flight Meals
# # Time Inquiry
#
# Class name:
# open_intent_classifier.model - DEBUG - Decoded output: Flight Booking Request
# open_intent_classifier.model - DEBUG - Full prompt: Topic %% Customer: tell me all the airports in the new york city area.
# END MESSAGE
# Choose one topic that matches customer's issue.
#  Options:
# # Abbreviation and Fare Code Meaning Inquiry
# # Aircraft Seating Capacity Inquiry
# # Aircraft Type Inquiry
# # Airfare and Fares Questions
# # Airline Information Request
# # Airport Distance Inquiry
# # Airport Ground Transportation and Cost Query
# # Airport Information and Queries
# # Airport Location Inquiry
# # Cheapest Fare Inquiry
# # Flight Booking Request
# # Flight Number Inquiry
# # Flight Quantity Inquiry
# # Flight Restriction Inquiry
# # Ground Transportation Cost Inquiry
# # Ground Transportation Inquiry
# # Inquiry about In-flight Meals
# # Time Inquiry
#
# Class name:
# open_intent_classifier.model - DEBUG - Decoded output: Airport Information and Queries
# open_intent_classifier.model - DEBUG - Full prompt: Topic %% Customer: please find all the flights from cincinnati to any airport in the new york city area that arrive next saturday before 6 pm.
# END MESSAGE
# Choose one topic that matches customer's issue.
#  Options:
# # Abbreviation and Fare Code Meaning Inquiry
# # Aircraft Seating Capacity Inquiry
# # Aircraft Type Inquiry
# # Airfare and Fares Questions
# # Airline Information Request
# # Airport Distance Inquiry
# # Airport Ground Transportation and Cost Query
# # Airport Information and Queries
# # Airport Location Inquiry
# # Cheapest Fare Inquiry
# # Flight Booking Request
# # Flight Number Inquiry
# # Flight Quantity Inquiry
# # Flight Restriction Inquiry
# # Ground Transportation Cost Inquiry
# # Ground Transportation Inquiry
# # Inquiry about In-flight Meals
# # Time Inquiry
#
# Class name:
# open_intent_classifier.model - DEBUG - Decoded output: Flight Booking Request
# open_intent_classifier.model - DEBUG - Full prompt: Topic %% Customer: find me a flight from cincinnati to any airport in the new york city area.
# END MESSAGE
# Choose one topic that matches customer's issue.
#  Options:
# # Abbreviation and Fare Code Meaning Inquiry
# # Aircraft Seating Capacity Inquiry
# # Aircraft Type Inquiry
# # Airfare and Fares Questions
# # Airline Information Request
# # Airport Distance Inquiry
# # Airport Ground Transportation and Cost Query
# # Airport Information and Queries
# # Airport Location Inquiry
# # Cheapest Fare Inquiry
# # Flight Booking Request
# # Flight Number Inquiry
# # Flight Quantity Inquiry
# # Flight Restriction Inquiry
# # Ground Transportation Cost Inquiry
# # Ground Transportation Inquiry
# # Inquiry about In-flight Meals
# # Time Inquiry
#
# Class name:
# open_intent_classifier.model - DEBUG - Decoded output: Flight Booking Request
# open_intent_classifier.model - DEBUG - Full prompt: Topic %% Customer: i 'd like to fly from miami to chicago on american airlines.
# END MESSAGE
# Choose one topic that matches customer's issue.
#  Options:
# # Abbreviation and Fare Code Meaning Inquiry
# # Aircraft Seating Capacity Inquiry
# # Aircraft Type Inquiry
# # Airfare and Fares Questions
# # Airline Information Request
# # Airport Distance Inquiry
# # Airport Ground Transportation and Cost Query
# # Airport Information and Queries
# # Airport Location Inquiry
# # Cheapest Fare Inquiry
# # Flight Booking Request
# # Flight Number Inquiry
# # Flight Quantity Inquiry
# # Flight Restriction Inquiry
# # Ground Transportation Cost Inquiry
# # Ground Transportation Inquiry
# # Inquiry about In-flight Meals
# # Time Inquiry
#
# Class name:
# open_intent_classifier.model - DEBUG - Decoded output: Airline Information Request
# 874it [00:22, 48.77it/s]open_intent_classifier.model - DEBUG - Full prompt: Topic %% Customer: i would like to book a round trip flight from kansas city to chicago.
# END MESSAGE
# Choose one topic that matches customer's issue.
#  Options:
# # Abbreviation and Fare Code Meaning Inquiry
# # Aircraft Seating Capacity Inquiry
# # Aircraft Type Inquiry
# # Airfare and Fares Questions
# # Airline Information Request
# # Airport Distance Inquiry
# # Airport Ground Transportation and Cost Query
# # Airport Information and Queries
# # Airport Location Inquiry
# # Cheapest Fare Inquiry
# # Flight Booking Request
# # Flight Number Inquiry
# # Flight Quantity Inquiry
# # Flight Restriction Inquiry
# # Ground Transportation Cost Inquiry
# # Ground Transportation Inquiry
# # Inquiry about In-flight Meals
# # Time Inquiry
#
# Class name:
# open_intent_classifier.model - DEBUG - Decoded output: Flight Booking Request
# open_intent_classifier.model - DEBUG - Full prompt: Topic %% Customer: find me a flight that flies from memphis to tacoma.
# END MESSAGE
# Choose one topic that matches customer's issue.
#  Options:
# # Abbreviation and Fare Code Meaning Inquiry
# # Aircraft Seating Capacity Inquiry
# # Aircraft Type Inquiry
# # Airfare and Fares Questions
# # Airline Information Request
# # Airport Distance Inquiry
# # Airport Ground Transportation and Cost Query
# # Airport Information and Queries
# # Airport Location Inquiry
# # Cheapest Fare Inquiry
# # Flight Booking Request
# # Flight Number Inquiry
# # Flight Quantity Inquiry
# # Flight Restriction Inquiry
# # Ground Transportation Cost Inquiry
# # Ground Transportation Inquiry
# # Inquiry about In-flight Meals
# # Time Inquiry
#
# Class name:
# open_intent_classifier.model - DEBUG - Decoded output: Flight Booking Request
# 876it [00:22, 39.44it/s]

# %%
from sklearn.metrics import classification_report
predictions = [pred.lower() for pred in predictions]
y = [label.lower() for label in df_test["label"].to_list()]

df_classification_report = pd.DataFrame(classification_report(y, predictions, output_dict=True)).T
df_classification_report
# Out:
# /home/serj/dev/open-intent-classifier/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/serj/dev/open-intent-classifier/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/serj/dev/open-intent-classifier/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                                     precision    recall  \
# abbreviation and fare code meaning inquiry           1.000000  1.000000
# aircraft seating capacity inquiry                    1.000000  0.952381
# aircraft type inquiry                                0.562500  1.000000
# airfare and fares questions                          0.500000  0.208333
# airline information request                          0.808511  1.000000
# airport distance inquiry                             0.833333  1.000000
# airport ground transportation and cost query         0.000000  0.000000
# airport information and queries                      0.640000  0.888889
# airport location inquiry                             0.307692  0.666667
# airport transportation cost inquiry                  0.000000  0.000000
# car rental inquiry                                   0.000000  0.000000
# cheapest fare inquiry                                0.000000  0.000000
# chicago to seattle saturday morning                  0.000000  0.000000
# delta flight 486                                     0.000000  0.000000
# fare code meaning inquiry                            0.000000  0.000000
# flight 608                                           0.000000  0.000000
# flight booking request                               0.973585  0.816456
# flight code meaning inquiry                          0.000000  0.000000
# flight distance inquiry                              0.000000  0.000000
# flight information and queries                       0.000000  0.000000
# flight list                                          0.000000  0.000000
# flight number inquiry                                1.000000  1.000000
# flight quantity inquiry                              0.200000  0.333333
# flight scheduled                                     0.000000  0.000000
# flight scheduled number inquiry                      0.000000  0.000000
# flight scheduled optional option option option ...   0.000000  0.000000
# flight us 1207                                       0.000000  0.000000
# flights                                              0.000000  0.000000
# flights from chicago to detroit                      0.000000  0.000000
# flights inquiry                                      0.000000  0.000000
# flights newark to los angeles wednesday morning      0.000000  0.000000
# friday inquiry                                       0.000000  0.000000
# ground transportation cost inquiry                   0.500000  0.571429
# ground transportation inquiry                        0.968750  0.861111
# inquiry about in-flight meals                        0.352941  1.000000
# list la                                              0.000000  0.000000
# new york to las vegas                                0.000000  0.000000
# new york to las vegas sunday afternoon               0.000000  0.000000
# newark to tampa                                      0.000000  0.000000
# quantity inquiry                                     0.000000  0.000000
# st. louis                                            0.000000  0.000000
# st. paul to kansas city friday night                 0.000000  0.000000
# st. petersburg to detroit                            0.000000  0.000000
# tampa to charlotte sunday morning                    0.000000  0.000000
# taxi fare code meaning inquiry                       0.000000  0.000000
# taxi service at the ontario airport                  0.000000  0.000000
# time inquiry                                         1.000000  1.000000
# weather inquiry                                      0.000000  0.000000
# accuracy                                             0.807078  0.807078
# macro avg                                            0.221819  0.256221
# weighted avg                                         0.914251  0.807078
#
#                                                     f1-score     support
# abbreviation and fare code meaning inquiry          1.000000   33.000000
# aircraft seating capacity inquiry                   0.975610   21.000000
# aircraft type inquiry                               0.720000    9.000000
# airfare and fares questions                         0.294118   48.000000
# airline information request                         0.894118   38.000000
# airport distance inquiry                            0.909091   10.000000
# airport ground transportation and cost query        0.000000    0.000000
# airport information and queries                     0.744186   18.000000
# airport location inquiry                            0.421053    6.000000
# airport transportation cost inquiry                 0.000000    0.000000
# car rental inquiry                                  0.000000    0.000000
# cheapest fare inquiry                               0.000000    0.000000
# chicago to seattle saturday morning                 0.000000    0.000000
# delta flight 486                                    0.000000    0.000000
# fare code meaning inquiry                           0.000000    0.000000
# flight 608                                          0.000000    0.000000
# flight booking request                              0.888124  632.000000
# flight code meaning inquiry                         0.000000    0.000000
# flight distance inquiry                             0.000000    0.000000
# flight information and queries                      0.000000    0.000000
# flight list                                         0.000000    0.000000
# flight number inquiry                               1.000000    8.000000
# flight quantity inquiry                             0.250000    3.000000
# flight scheduled                                    0.000000    0.000000
# flight scheduled number inquiry                     0.000000    0.000000
# flight scheduled optional option option option ...  0.000000    0.000000
# flight us 1207                                      0.000000    0.000000
# flights                                             0.000000    0.000000
# flights from chicago to detroit                     0.000000    0.000000
# flights inquiry                                     0.000000    0.000000
# flights newark to los angeles wednesday morning     0.000000    0.000000
# friday inquiry                                      0.000000    0.000000
# ground transportation cost inquiry                  0.533333    7.000000
# ground transportation inquiry                       0.911765   36.000000
# inquiry about in-flight meals                       0.521739    6.000000
# list la                                             0.000000    0.000000
# new york to las vegas                               0.000000    0.000000
# new york to las vegas sunday afternoon              0.000000    0.000000
# newark to tampa                                     0.000000    0.000000
# quantity inquiry                                    0.000000    0.000000
# st. louis                                           0.000000    0.000000
# st. paul to kansas city friday night                0.000000    0.000000
# st. petersburg to detroit                           0.000000    0.000000
# tampa to charlotte sunday morning                   0.000000    0.000000
# taxi fare code meaning inquiry                      0.000000    0.000000
# taxi service at the ontario airport                 0.000000    0.000000
# time inquiry                                        1.000000    1.000000
# weather inquiry                                     0.000000    0.000000
# accuracy                                            0.807078    0.807078
# macro avg                                           0.230482  876.000000
# weighted avg                                        0.849094  876.000000
